# %%
# !git clone https://github.com/IBM/Multi-GNN.git
# Out:
# Cloning into 'Multi-GNN'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 86 (delta 25), reused 23 (delta 23), pack-reused 53 (from 1)
# Receiving objects: 100% (86/86), 35.58 KiB | 1.15 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
# !pip install torch==2.0.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 67.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 53.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 6.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # GIN model

# %%
# %cd Multi-GNN
# !python main.py --data Small_HI --model gin
# Out:
# /content/Multi-GNN
# 2024-08-18 11:16:42,466 [INFO ] Random seed set as 1
# 2024-08-18 11:16:42,467 [INFO ] Retrieving data
# 2024-08-18 11:16:43,049 [INFO ] Available Edge Features: ['EdgeID', 'from_id', 'to_id', 'Timestamp', 'Amount Sent', 'Sent Currency', 'Amount Received', 'Received Currency', 'Payment Format', 'Is Laundering']
# 2024-08-18 11:16:51,389 [INFO ] Illicit ratio = 179 / 487856 = 0.04%
# 2024-08-18 11:16:51,389 [INFO ] Number of nodes (holdings doing transcations) = 323159
# 2024-08-18 11:16:51,389 [INFO ] Number of transactions = 487856
# 2024-08-18 11:16:51,389 [INFO ] Edge features being used: ['Timestamp', 'Amount Received', 'Received Currency', 'Payment Format']
# 2024-08-18 11:16:51,389 [INFO ] Node features being used: ['Feature'] ("Feature" is a placeholder feature of all 1s)
# 2024-08-18 11:16:51,418 [INFO ] number of days and transactions in the data: 6 days, 487856 transactions
# 2024-08-18 11:16:51,480 [INFO ] Calculate split: [[0], [1, 2], [3, 4, 5]]
# ...

# %% [markdown]
# # GAT model

# %%
# !python main.py --data Small_HI --model gat
# Out:
# 2024-08-18 11:46:35,816 [INFO ] Random seed set as 1
# 2024-08-18 11:46:35,816 [INFO ] Retrieving data
# 2024-08-18 11:46:36,270 [INFO ] Available Edge Features: ['EdgeID', 'from_id', 'to_id', 'Timestamp', 'Amount Sent', 'Sent Currency', 'Amount Received', 'Received Currency', 'Payment Format', 'Is Laundering']
# 2024-08-18 11:46:43,498 [INFO ] Illicit ratio = 179 / 487856 = 0.04%
# 2024-08-18 11:46:43,498 [INFO ] Number of nodes (holdings doing transcations) = 323159
# 2024-08-18 11:46:43,498 [INFO ] Number of transactions = 487856
# 2024-08-18 11:46:43,498 [INFO ] Edge features being used: ['Timestamp', 'Amount Received', 'Received Currency', 'Payment Format']
# 2024-08-18 11:46:43,498 [INFO ] Node features being used: ['Feature'] ("Feature" is a placeholder feature of all 1s)
# 2024-08-18 11:46:43,524 [INFO ] number of days and transactions in the data: 6 days, 487856 transactions
# 2024-08-18 11:46:43,560 [INFO ] Calculate split: [[0], [1, 2], [3, 4, 5]]
# ...

# %% [markdown]
# # GCN model

# %%
# !python main.py --data Small_HI --model rgcn
# Out:
# 2024-08-18 14:34:58,671 [INFO ] Random seed set as 1
# 2024-08-18 14:34:58,672 [INFO ] Retrieving data
# 2024-08-18 14:34:59,239 [INFO ] Available Edge Features: ['EdgeID', 'from_id', 'to_id', 'Timestamp', 'Amount Sent', 'Sent Currency', 'Amount Received', 'Received Currency', 'Payment Format', 'Is Laundering']
# 2024-08-18 14:35:07,308 [INFO ] Illicit ratio = 179 / 487856 = 0.04%
# 2024-08-18 14:35:07,308 [INFO ] Number of nodes (holdings doing transcations) = 323159
# 2024-08-18 14:35:07,308 [INFO ] Number of transactions = 487856
# 2024-08-18 14:35:07,308 [INFO ] Edge features being used: ['Timestamp', 'Amount Received', 'Received Currency', 'Payment Format']
# 2024-08-18 14:35:07,308 [INFO ] Node features being used: ['Feature'] ("Feature" is a placeholder feature of all 1s)
# 2024-08-18 14:35:07,330 [INFO ] number of days and transactions in the data: 6 days, 487856 transactions
# 2024-08-18 14:35:07,355 [INFO ] Calculate split: [[0], [1, 2], [3, 4, 5]]
# ...

# %%
# !python main.py --data Small_HI --model pna
# Out:
# 2024-08-18 15:37:13,554 [INFO ] Random seed set as 1
# 2024-08-18 15:37:13,554 [INFO ] Retrieving data
# 2024-08-18 15:37:14,165 [INFO ] Available Edge Features: ['EdgeID', 'from_id', 'to_id', 'Timestamp', 'Amount Sent', 'Sent Currency', 'Amount Received', 'Received Currency', 'Payment Format', 'Is Laundering']
# 2024-08-18 15:37:23,029 [INFO ] Illicit ratio = 179 / 487856 = 0.04%
# 2024-08-18 15:37:23,029 [INFO ] Number of nodes (holdings doing transcations) = 323159
# 2024-08-18 15:37:23,029 [INFO ] Number of transactions = 487856
# 2024-08-18 15:37:23,029 [INFO ] Edge features being used: ['Timestamp', 'Amount Received', 'Received Currency', 'Payment Format']
# 2024-08-18 15:37:23,029 [INFO ] Node features being used: ['Feature'] ("Feature" is a placeholder feature of all 1s)
# 2024-08-18 15:37:23,068 [INFO ] number of days and transactions in the data: 6 days, 487856 transactions
# 2024-08-18 15:37:23,119 [INFO ] Calculate split: [[0], [1, 2], [3, 4, 5]]
# ...

# %%
# !ls /content/Multi-GNN/
# Out:
# data_config.json  format_kaggle_files.py      LICENSE		   models.py	training.py
# data_loading.py   formatted_transactions.csv  logs		   __pycache__	train_util.py
# data_util.py	  HI-Small_Trans.csv	      main.py		   README.md	util.py
# env.yml		  inference.py		      model_settings.json  Small_HI	wandb

# %%
# !pip install wandb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 25.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.7 MB/s eta 0:00:00
# ...
